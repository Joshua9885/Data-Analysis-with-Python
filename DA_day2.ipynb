# %%
a=[8,2,7,3,6,4]
a.sort()
print(a)

# %%
a=[4,7,1,6,9,8]
b=sorted(a)
print(a)
print(b)

# %%
#Tuple
a=(1,5,7,4,3,6,9)
b=sorted(a)
print(a)
print(b)

# %%
import numpy as np

# %%
A= np.arange(1,13).reshape(3,4)
print(A)

# %%
A=np.linspace(2,8,10).reshape(2,5)
print(A)

# %%
B=np.array([21,42,85,69,23,36,57,32]).reshape(2,2,2)
print(B)

# %%
#reshape changes the shape of original array,changes need stored in new variable
B=np.array([21,42,85,69,23,36,57,32])
c=B.reshape(2,2,2)
print(B)
print(c)

# %%
A=np.array([30,21,74,95,35,])#list will throw an error while arrays iterate themselves
B=np.array([2,14,7,32,65])
C=A-B
print(C)

# %%
#Array operations
C=np.array([42,12,47,65]).reshape(2,2)
D=np.array([2,14,32,65]).reshape(2,2)
print(C)
print("_____________________")
print(D)
print("_____________________")
E=C*D
print(E)

# %%
C=np.array([42,12,47,65]).reshape(2,2)
D=np.array([2,14,32,65]).reshape(2,2)
print(C)
print("_____________________")
print(D)
print("_____________________")
E=C@D
print(E)

# %%
C=np.array([42,12,47,65]).reshape(2,2)
D=np.array([2,14,32,65]).reshape(2,2)
print(C)
print("_____________________")
print(D)
print("_____________________")
E=C.dot(D)
print(E)

# %%
A=np.array([30,21,74,95,35,])#Min Max only for accepts Numeric and float data tpes
print(A.max())
print(A.min())

# %%
C=np.array([42,12,47,65,32,4,85,50]).reshape(2,4)
print("_____________________")
print(C.max(axis=0))#axis 0 is coloumn
print("_____________________")
print(C.max(axis=1))#axis 1 is row

# %%
C=np.array([42,12,47,65,32,4,85,50]).reshape(2,4)
print("_____________________")
print(C.min(axis=0))#axis 0 is coloumn
print("_____________________")
print(C.min(axis=1))#axis 1 is row

# %%
#Joining arrays
C=np.array([42,12,47,65]).reshape(2,2)
D=np.array([2,14,32,65]).reshape(2,2)
print(C)
print("_____________________")
print(D)
print("_____________________")
print(np.vstack((C,D)))

# %%
C=np.array([42,12,47,65]).reshape(2,2)
D=np.array([2,14,32,65]).reshape(2,2)
print(C)
print("_____________________")
print(D)
print("_____________________")
print(np.hstack((C,D)))

# %%
C=np.array([42,12,47,65]).reshape(2,2)
D=np.array([2,14,32,65]).reshape(2,2)
print(C)
print("_____________________")
print(D)
print("_____________________")
print(np.stack((C,D),axis=1))

# %%
A=np.arange(30).reshape(2,3,5)
print(A)
print("After dstack")
print(np.dstack(A))#no of rows---->no of groups
#no of col in every group --->no of rows in every group

# %%
#splitting arrays
A=np.arange(28).reshape(4,7)
print(A)
print("After splitting")
print(np.vsplit(A,4))

# %%
A=np.arange(28).reshape(4,7)
print(A)
print("After splitting")
print(np.hsplit(A,7))

# %%
A=np.arange(28).reshape(4,7)
print(A)
print("After splitting")
print(np.vsplit(A,(2,3)))

# %%
A=np.arange(28).reshape(4,7)
print(A)
print("After splitting")
print(np.hsplit(A,(2,5)))

# %%
A=np.arange(18).reshape(3,6)
print(A)
print(A.argmax())

# %%
A=np.array([12,75,41,32,6,2,14,69,45,74,21,10,3,11,19]).reshape(5,3)
print(A)
print(A.argmax())

# %%
A=np.array([12,75,41,32,6,2,14,69,45,74,21,10,3,11,19]).reshape(5,3)
print(A)
print(A.argmax(axis=0))

# %%
A=np.array([12,75,41,32,6,2,14,69,45,74,21,10,3,11,19]).reshape(5,3)
print(A)
print(A.argmax(axis=1))

# %%
A=np.array([12,75,41,32,6,2,14,69,45,74,21,10,3,11,19]).reshape(5,3)
print(A)
print(A.argmin())

# %%
A=np.array([12,75,41,32,6,2,14,69,45,74,21,10,3,11,19]).reshape(5,3)
print(A)
print(A.argmin(axis=0))

# %%
A=np.array([12,75,41,32,6,2,14,69,45,74,21,10,3,11,19]).reshape(5,3)
print(A)
print(A.argmin(axis=1))

# %%
#Statistics -mean,median,std,var
A=np.array([30,21,74,95,35,])
print("Mean: ",np.mean(A))
print("Median: ",np.median(A))
print("Stard deviation: ",np.std(A))
print("Variance: ",np.var(A))

# %%
#Trigonometry
A=np.pi
print(A)#radiance

# %%
np.rad2deg(A)

# %%
A=[np.pi/4, np.pi/3, np.pi/2, np.pi]
print(A)

# %%
np.rad2deg(A)

# %%
C=np.array([30,45,60,90,120,180])
D=np.deg2rad(C)
print(D)

# %%
np.sin(C)

# %%
np.cos(C)

# %%
np.tan(C)

# %%
np.arcsin(C)

# %%
np.arccos(C)

# %%
np.arctan(C)

# %%
a=6
b=4
print(np.hypot(a,b))

# %%
#searching on array
A=np.array([30,21,74,95,35,])
print(np.where(A==21))

# %%
A=np.array([30,21,74,95,35,])
print(np.where(A%5==0))

# %%
A=np.array([30,21,74,95,35,])
print(np.searchsorted(A,21))

# %%
#Linear algebra universal functions
import numpy as np
A=np.array([30,21,74,95,35])
C=np.array([42,12,47,65,12])
print(np.add(A,C))
print(np.subtract(A,C))
print(np.divide(A,C))
print(np.mod(A,C))
print(np.multiply(A,C))

# %%
A=np.array([30,21,74,95,35])
print(np.sort(A))

# %%
print(np.diff(A))

# %%
A=np.array([30,65,74,12,35])
C=np.array([42,12,47,65,12])
print(np.union1d(A,C))
print(np.intersect1d(A,C))
print(np.setdiff1d(A,C))

# %%
#rounding
a=np.trunc([1.23,23.43,54.23,11.2,78.09])
print(a)

# %%
a=np.fix([1.23,23.43,54.23,11.2,78.09])
print(a)

# %%
a=np.around([1.23,23.43,54.23,11.2,78.09])
print(a)

# %%
a=np.floor([1.23,23.43,54.23,11.2,78.09])
print(a)

# %%
a=np.ceil([1.23,23.43,54.23,11.2,78.09])
print(a)

# %% [markdown]
# More functions

# %%
A=np.array([30,65,74,12,35])
print(np.cumsum(A))

# %%
A=np.array([30,65,74,12,35])
print(np.cumprod(A))

# %%
np.lcm(26,81)

# %%
print(np.gcd(28,45))

# %%
A=np.array([30,65,74,12,35])
print(np.lcm.reduce(A))

# %%
A=np.array([[30,65],[12,35]])
print(np.linalg.inv(A))

# %%
from numpy import random as rd

# %%
A=rd.rand()
print(A)

# %%
A=rd.rand(10)
print(A)

# %%
a=rd.randint(6)
print(a)

# %%
a=rd.randint(10,size=6)
print(a)

# %% [markdown]
# Joins

# %%
A=np.array([30,65,74,12,35])
C=np.array([42,12,47,65,12])
print(np.inner(A,C))

# %%
A=np.array([30,65,74,12,35])
C=np.array([42,12,47,65,12])
print(np.outer(A,C))

# %%
a=np.array([2,4,6])
b=np.array([5,9,7])
print(np.cross(a,b))
