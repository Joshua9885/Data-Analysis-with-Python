# %%
import seaborn as sns

# %%
# titanic
ti=sns.load_dataset("titanic")
ti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.relplot(data=ti,x='who',y='class',col='alive')

# %%
sns.relplot(data=ti,x='who',y='class',hue='alive')

# %%
sns.relplot(data=ti,x='who',y='class',hue='class',palette="bright")

# %%
sns.relplot(data=ti,x='age',y='fare',kind="line")

# %%
sns.catplot(data=ti,x="class",y="fare",kind="violin")

# %%
sns.barplot(data=ti,x="class",y="alone",hue="sex")
# Out:
# <Axes: xlabel='class', ylabel='alone'>

# %%
# iris
ir=sns.load_dataset("iris")
ir
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(data=ir,x="sepal_width",y="sepal_length",col="species")

# %%
sns.relplot(data=ir,x="sepal_width",y="sepal_length",hue="species",palette="bright")

# %%
sns.barplot(data=ir,x="petal_width",y="sepal_length",hue="species")
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
sns.catplot(data=ir,x="petal_width",y="petal_length",hue="species",kind="violin")

# %%
# exercise
ex=sns.load_dataset("exercise")
ex
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.relplot(data=ex,x="id",y="pulse",col="diet")

# %%
sns.relplot(data=ex,x="id",y="pulse",hue="diet")

# %%
sns.relplot(data=ex,x="id",y="pulse",hue="kind")

# %%
sns.relplot(data=ex,x="id",y="kind",hue="diet",kind="line")

# %%
sns.barplot(data=ex,x="id",y="diet",hue="kind")
# Out:
# <Axes: xlabel='id', ylabel='diet'>

# %%
sns.catplot(data=ex,x="id",y="diet",hue="kind",kind="violin")

# %%
sns.catplot(data=ex,x="time",y="pulse",hue="kind",kind="violin")

# %%
sns.boxplot(data=ex,x="id",y="diet",hue="kind")
# Out:
# <Axes: xlabel='id', ylabel='diet'>

# %%
sns.countplot(data=ex)
# Out:
# <Axes: ylabel='count'>

# %%
sns.stripplot(data=ex,x="id",y="diet",hue="kind")
# Out:
# <Axes: xlabel='id', ylabel='diet'>

# %%
sns.pointplot(data=ex,x="time",y="pulse",hue="kind")
# Out:
# <Axes: xlabel='time', ylabel='pulse'>

# %%
sns.swarmplot(data=ex,x="id",y="pulse",hue="kind")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='id', ylabel='pulse'>
