# %%
#import pandas
import pandas as pd

# %%
#series
#index of coloumn
#pd.Series(col Index)
a=['Sai','Gagan','Nagraj','Balu','Ganesh']
r=pd.Series(a,index=[1,2,3,4,5])
print(r)
# Out:
# 1       Sai
# 2     Gagan
# 3    Nagraj
# 4      Balu
# 5    Ganesh
# dtype: object

# %%
#loading CSV
re=pd.read_csv("/content/diabetcsv.csv")
re
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
di=pd.read_excel("/content/diabetes.xlsx")
di
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grade=pd.read_csv("/content/grades.txt")
grade
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade
# 0                  Joe K 9.8 10 9.9 A+
# 1               Rajesh M 8.9 9.1 9.3 A
# 2               Kissan V 9.9 9.3 9.2 A
# 3                   Mary N 7.7 8 7.1 B
# 4                Jeen K 9.8 9.1 9.9 A+
# 5                  Raj M 8.9 9.1 9.3 A
# 6                 Hassan V 9.9 9 9.2 A
# 7                   Mari N 7.7 8 7.1 B
# 8                Jess K 9.8 9.1 9.9 A+
# 9                 Rajini M 7 9.1 9.3 A
# 10               Kiran V 9.9 9.3 9.2 A
# 11                  Maya N 7.7 8 7.1 B
# 12              Jolin K 9.8 9.1 9.9 A+
# 13                  Riya M 8 9.1 9.3 A
# 14                Sana V 9.9 9.3 9.2 A
# 15                    Mark N 7.7 8 7 B

# %%
demo=pd.read_csv("/content/demodt.txt")
demo
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
dia=pd.read_excel("/content/diabetes.xlsx",sheet_name="dora")
dia
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
di.describe()#describing a data frame
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
nul=pd.read_csv("/content/grades_withnulls.csv")
nul
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#dropna()doesnot reflect main data by deafult
#we can overcome this by using inplace=TRUE in dropna function
nul=pd.read_csv("/content/grades_withnulls.csv")
nul.dropna()
nul
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
nul.dropna(inplace=True)
nul
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df.fillna(555)#filling null values with random value
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.fillna(555,inplace=True)#filling null values with random value and saving
df
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df1=pd.read_csv("/content/grades_withnulls.csv")
mv=df1['SEM1'].mean()
print(mv)
df1.fillna(mv,inplace=True)
df1
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#acces the data
#loc=integer location,index
#loc=field names,index
#df_name.loc[index]--->rows
#df_name.loc[start:stop]--->rows in range
#df_name.loc[row_index,col_name]--->rows&col
df.loc[0:5]#first record
# Out:
#     Names Initials  SEM1  SEM2   SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0    9.9    A+       1
# 1  Rajesh        M   8.9   9.1    9.3     A       1
# 2  Kissan        V   9.9   9.8   10.0     A       0
# 3    Mary        N   7.7   8.0  555.0     B       0
# 4    Jeen        K   9.8   9.1    9.9    A+       1
# 5     Raj        M   8.9   9.1    9.3     A       1

# %%
df.loc[0:5,"SEM1"]
# Out:
# 0    9.8
# 1    8.9
# 2    9.9
# 3    7.7
# 4    9.8
# 5    8.9
# Name: SEM1, dtype: float64

# %%
df.loc[df.index==1,"Grade"]#accesing specific row and coloumn
# Out:
# 1    A
# Name: Grade, dtype: object

# %%
#accessing range of coloumns and rows
df.iloc[0:5,0:2]
# Out:
#     Names Initials
# 0     Joe        K
# 1  Rajesh        M
# 2  Kissan        V
# 3    Mary        N
# 4    Jeen        K

# %%
df[df.Grade=='A']
# Out:
#      Names Initials   SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M    8.9   9.1   9.3     A       1
# 2   Kissan        V    9.9   9.8  10.0     A       0
# 5      Raj        M    8.9   9.1   9.3     A       1
# 6   Hassan        V    9.9   9.0   9.2     A       1
# 9   Rajini        M  555.0   9.1   9.3     A       0
# 10   Kiran        V  555.0   9.3   9.2     A       0
# 13  Rajesh        M    8.9   9.1   9.3     A       1
# 14    Riya        M    9.3   9.9  10.0     A       1
# 15    Sana        V    9.9   9.3   9.2     A       0

# %%
#print record who got 8.9 in sem1
df[df.SEM1==8.9]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
df.loc[df['SEM1']>8.9,['Names']]#loc[index,coloumns]
# Out:
#      Names
# 0      Joe
# 2   Kissan
# 4     Jeen
# 6   Hassan
# 8     Jess
# 9   Rajini
# 10   Kiran
# 12   Jolin
# 14    Riya
# 15    Sana

# %%
#print the grades of student who got more than 9 in sem3
df.loc[df['SEM3']>9.7,['Grade']]
# Out:
#    Grade
# 0     A+
# 2      A
# 3      B
# 4     A+
# 8     A+
# 12    A+
# 14     A

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# 16    Mark        N    7.7   8.0    7.0     B       0

# %%
df.head()#it returns frist five records by deafult
# Out:
#     Names Initials  SEM1  SEM2   SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0    9.9    A+       1
# 1  Rajesh        M   8.9   9.1    9.3     A       1
# 2  Kissan        V   9.9   9.8   10.0     A       0
# 3    Mary        N   7.7   8.0  555.0     B       0
# 4    Jeen        K   9.8   9.1    9.9    A+       1

# %%
df.tail()#it returns last five records by deafult
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 11   Maya        N   7.7   8.0   7.1     B       0
# 12  Jolin        K   9.8   9.1   9.9    A+       1
# 14   Riya        M   9.3   9.9  10.0     A       1
# 15   Sana        V   9.9   9.3   9.2     A       0
# 16   Mark        N   7.7   8.0   7.0     B       0

# %%
df.loc[df.index==1]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#accesing coloumns
df.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
col=list(df.columns)
print(col)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
#renaming the colomns
df.rename(columns={'Grade':'GPA'})
df.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#renaming the colomns
df.rename(columns={'Grade':'GPA'},inplace=True)
df.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed'], dtype='object')

# %%
from typing_extensions import get_overloads
#creating a new column
#dfname["newcolumn"]=values
df["Conduct"]="Good"
df
# Out:
#      Names Initials   SEM1  SEM2   SEM3 GPA  Placed Conduct
# 0      Joe        K    9.8  10.0    9.9  A+       1    Good
# 1   Rajesh        M    8.9   9.1    9.3   A       1    Good
# 2   Kissan        V    9.9   9.8   10.0   A       0    Good
# 3     Mary        N    7.7   8.0  555.0   B       0    Good
# 4     Jeen        K    9.8   9.1    9.9  A+       1    Good
# 5      Raj        M    8.9   9.1    9.3   A       1    Good
# 6   Hassan        V    9.9   9.0    9.2   A       1    Good
# 7     Mari        N    7.7   8.0    7.1   B       1    Good
# 8     Jess        K  555.0   9.1    9.9  A+       1    Good
# 9   Rajini        M  555.0   9.1    9.3   A       0    Good
# 10   Kiran        V  555.0   9.3    9.2   A       0    Good
# 11    Maya        N    7.7   8.0    7.1   B       0    Good
# 12   Jolin        K    9.8   9.1    9.9  A+       1    Good
# 14    Riya        M    9.3   9.9   10.0   A       1    Good
# 15    Sana        V    9.9   9.3    9.2   A       0    Good
# ...

# %%
df['Average']=(df.SEM1+df.SEM2+df.SEM3)/3
df
# Out:
#      Names Initials   SEM1  SEM2   SEM3 GPA  Placed Conduct     Average
# 0      Joe        K    9.8  10.0    9.9  A+       1    Good    9.900000
# 1   Rajesh        M    8.9   9.1    9.3   A       1    Good    9.100000
# 2   Kissan        V    9.9   9.8   10.0   A       0    Good    9.900000
# 3     Mary        N    7.7   8.0  555.0   B       0    Good  190.233333
# 4     Jeen        K    9.8   9.1    9.9  A+       1    Good    9.600000
# 5      Raj        M    8.9   9.1    9.3   A       1    Good    9.100000
# 6   Hassan        V    9.9   9.0    9.2   A       1    Good    9.366667
# 7     Mari        N    7.7   8.0    7.1   B       1    Good    7.600000
# 8     Jess        K  555.0   9.1    9.9  A+       1    Good  191.333333
# 9   Rajini        M  555.0   9.1    9.3   A       0    Good  191.133333
# 10   Kiran        V  555.0   9.3    9.2   A       0    Good  191.166667
# 11    Maya        N    7.7   8.0    7.1   B       0    Good    7.600000
# ...

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
mv=df['SEM1'].mean()
print(mv)
df.fillna(mv,inplace=True)
df.drop_duplicates(inplace=True)
df
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
df['Average']=(df.SEM1+df.SEM2+df.SEM3)/3
df["Conduct"]="Good"
df
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed   Average Conduct
# 0      Joe        K  9.800000  10.0   9.900000    A+       1  9.900000    Good
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1  9.100000    Good
# 2   Kissan        V  9.900000   9.8  10.000000     A       0  9.900000    Good
# 3     Mary        N  7.700000   8.0   8.992857     B       0  8.230952    Good
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1  9.600000    Good
# 5      Raj        M  8.900000   9.1   9.300000     A       1  9.100000    Good
# 6   Hassan        V  9.900000   9.0   9.200000     A       1  9.366667    Good
# 7     Mari        N  7.700000   8.0   7.100000     B       1  7.600000    Good
# 8     Jess        K  8.992857   9.1   9.900000    A+       1  9.330952    Good
# 9   Rajini        M  8.992857   9.1   9.300000     A       0  9.130952    Good
# 10   Kiran        V  8.992857   9.3   9.200000     A       0  9.164286    Good
# ...

# %%
#ploting with pandas
df['SEM1'].plot.line()
# Out:
# <Axes: >

# %%
df[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.plot(kind="scatter",x="Names",y="Average")
# Out:
# <Axes: xlabel='Names', ylabel='Average'>

# %%
df.plot(kind="scatter",x="Average",y="Names")
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
df.plot(kind="bar",x="Names",y="Average")
# Out:
# <Axes: xlabel='Names'>

# %%
df.plot(kind="hist",x="Names",y="Average")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed   Average Conduct
# 0      Joe        K  9.800000  10.0   9.900000    A+       1  9.900000    Good
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1  9.100000    Good
# 2   Kissan        V  9.900000   9.8  10.000000     A       0  9.900000    Good
# 3     Mary        N  7.700000   8.0   8.992857     B       0  8.230952    Good
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1  9.600000    Good
# 5      Raj        M  8.900000   9.1   9.300000     A       1  9.100000    Good
# 6   Hassan        V  9.900000   9.0   9.200000     A       1  9.366667    Good
# 7     Mari        N  7.700000   8.0   7.100000     B       1  7.600000    Good
# 8     Jess        K  8.992857   9.1   9.900000    A+       1  9.330952    Good
# 9   Rajini        M  8.992857   9.1   9.300000     A       0  9.130952    Good
# 10   Kiran        V  8.992857   9.3   9.200000     A       0  9.164286    Good
# ...

# %%
df.to_csv("DA_PY.csv")
