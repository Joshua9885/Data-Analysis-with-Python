# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
import pandas as pd

# %%
df=pd.read_csv("/content/Earth.txt",sep='.')
df
# Out:
# Empty DataFrame
# Columns: [Earth is the third planet from the Sun and the only astronomical object known to harbor life,  This is enabled by Earth being a water world, the only one in the Solar System sustaining liquid surface water,  Almost all of Earth's water is contained in its global ocean, covering 70, 8% of Earth's crust,  The remaining 29, 2% of Earth's crust is land, most of which is located in the form of continental landmasses within one hemisphere, Earth's land hemisphere,  Most of Earth's land is somewhat humid and covered by vegetation, while large sheets of ice at Earth's polar deserts retain more water than Earth's groundwater, lakes, rivers and atmospheric water combined,  Earth's crust consists of slowly moving tectonic plates, which interact to produce mountain ranges, volcanoes, and earthquakes,  Earth has a liquid outer core that generates a magnetosphere capable of deflecting most of the destructive solar winds and cosmic radiation, Unnamed: 9]
# Index: []

# %%
# Tkoenizing the words
tokenizer=Tokenizer()
tokenizer.fit_on_texts(df)
total_words=len(tokenizer.word_index)+1
print(total_words)
# Out:
# 97

# %%
# Creating input sequences and their corresponding next words
input_sequences = []
for sentence in df:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[7, 4],
#  [7, 4, 2],
#  [7, 4, 2, 21],
#  [7, 4, 2, 21, 22],
#  [7, 4, 2, 21, 22, 23],
#  [7, 4, 2, 21, 22, 23, 2],
#  [7, 4, 2, 21, 22, 23, 2, 24],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29],
#  [30, 4],
#  [30, 4, 31],
#  [30, 4, 31, 15],
#  [30, 4, 31, 15, 7],
#  [30, 4, 31, 15, 7, 32],
#  [30, 4, 31, 15, 7, 32, 8],
#  [30, 4, 31, 15, 7, 32, 8, 6],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9, 2],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9, 2, 17],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9, 2, 17, 34],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9, 2, 17, 34, 35],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9, 2, 17, 34, 35, 18],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9, 2, 17, 34, 35, 18, 36],
#  [30, 4, 31, 15, 7, 32, 8, 6, 33, 2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6],
#  [37, 38],
#  [37, 38, 1],
#  [37, 38, 1, 3],
#  [37, 38, 1, 3, 6],
#  [37, 38, 1, 3, 6, 4],
#  [37, 38, 1, 3, 6, 4, 39],
#  [37, 38, 1, 3, 6, 4, 39, 9],
#  [37, 38, 1, 3, 6, 4, 39, 9, 40],
#  [37, 38, 1, 3, 6, 4, 39, 9, 40, 41],
#  [37, 38, 1, 3, 6, 4, 39, 9, 40, 41, 42],
#  [37, 38, 1, 3, 6, 4, 39, 9, 40, 41, 42, 43],
#  [37, 38, 1, 3, 6, 4, 39, 9, 40, 41, 42, 43, 44],
#  [45, 1],
#  [45, 1, 3],
#  [45, 1, 3, 10],
#  [2, 46],
#  [2, 46, 47],
#  [48, 1],
#  [48, 1, 3],
#  [48, 1, 3, 10],
#  [48, 1, 3, 10, 4],
#  [48, 1, 3, 10, 4, 11],
#  [48, 1, 3, 10, 4, 11, 12],
#  [48, 1, 3, 10, 4, 11, 12, 1],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50, 1],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50, 1, 51],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53, 16],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53, 16, 20],
#  [48, 1, 3, 10, 4, 11, 12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53, 16, 20, 3],
#  [48,
#   1,
#   3,
#   10,
#   4,
#   11,
#   12,
#   1,
#   19,
#   4,
#   49,
#   9,
#   2,
#   50,
#   1,
#   51,
#   52,
#   53,
#   16,
#   20,
#   3,
#   11],
#  [48,
#   1,
#   3,
#   10,
#   4,
#   11,
#   12,
#   1,
#   19,
#   4,
#   49,
#   9,
#   2,
#   50,
#   1,
#   51,
#   52,
#   53,
#   16,
#   20,
#   3,
#   11,
#   20],
#  [12, 1],
#  [12, 1, 3],
#  [12, 1, 3, 11],
#  [12, 1, 3, 11, 4],
#  [12, 1, 3, 11, 4, 54],
#  [12, 1, 3, 11, 4, 54, 55],
#  [12, 1, 3, 11, 4, 54, 55, 5],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59, 60],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59, 60, 1],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59, 60, 1, 61],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59, 60, 1, 61, 62],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59, 60, 1, 61, 62, 3],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59, 60, 1, 61, 62, 3, 63],
#  [12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57, 58, 59, 60, 1, 61, 62, 3, 63, 64],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3,
#   68],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3,
#   68,
#   69],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3,
#   68,
#   69,
#   70],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3,
#   68,
#   69,
#   70,
#   5],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3,
#   68,
#   69,
#   70,
#   5,
#   71],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3,
#   68,
#   69,
#   70,
#   5,
#   71,
#   6],
#  [12,
#   1,
#   3,
#   11,
#   4,
#   54,
#   55,
#   5,
#   56,
#   15,
#   57,
#   58,
#   59,
#   60,
#   1,
#   61,
#   62,
#   3,
#   63,
#   64,
#   65,
#   66,
#   6,
#   67,
#   3,
#   68,
#   69,
#   70,
#   5,
#   71,
#   6,
#   72],
#  [3, 10],
#  [3, 10, 73],
#  [3, 10, 73, 1],
#  [3, 10, 73, 1, 74],
#  [3, 10, 73, 1, 74, 75],
#  [3, 10, 73, 1, 74, 75, 76],
#  [3, 10, 73, 1, 74, 75, 76, 77],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78, 14],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78, 14, 79],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78, 14, 79, 80],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78, 14, 79, 80, 81],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78, 14, 79, 80, 81, 82],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78, 14, 79, 80, 81, 82, 5],
#  [3, 10, 73, 1, 74, 75, 76, 77, 19, 78, 14, 79, 80, 81, 82, 5, 83],
#  [7, 84],
#  [7, 84, 8],
#  [7, 84, 8, 18],
#  [7, 84, 8, 18, 85],
#  [7, 84, 8, 18, 85, 86],
#  [7, 84, 8, 18, 85, 86, 87],
#  [7, 84, 8, 18, 85, 86, 87, 88],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17, 93],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17, 93, 5],
#  [7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17, 93, 5, 94],
#  [95, 96]]

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length,padding='pre')

# %%
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0,  7,  4],
#        [ 0,  0,  0, ...,  7,  4,  2],
#        [ 0,  0,  0, ...,  4,  2, 21],
#        ...,
#        [ 0,  0,  0, ..., 17, 93,  5],
#        [ 0,  0,  0, ..., 93,  5, 94],
#        [ 0,  0,  0, ...,  0, 95, 96]], dtype=int32)

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
#compiling the model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
#training Model
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 5/5 - 3s - loss: 4.5887 - accuracy: 0.0211 - 3s/epoch - 515ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 4.4233 - accuracy: 0.0845 - 108ms/epoch - 22ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 4.2402 - accuracy: 0.1479 - 103ms/epoch - 21ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 4.0535 - accuracy: 0.1479 - 113ms/epoch - 23ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.9162 - accuracy: 0.1549 - 111ms/epoch - 22ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 3.7633 - accuracy: 0.2465 - 118ms/epoch - 24ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 3.5853 - accuracy: 0.3169 - 129ms/epoch - 26ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 3.4382 - accuracy: 0.3662 - 119ms/epoch - 24ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 3.2815 - accuracy: 0.4225 - 136ms/epoch - 27ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 3.1170 - accuracy: 0.4366 - 111ms/epoch - 22ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 2.9502 - accuracy: 0.5141 - 103ms/epoch - 21ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 2.8128 - accuracy: 0.5775 - 106ms/epoch - 21ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.6483 - accuracy: 0.5775 - 119ms/epoch - 24ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.5217 - accuracy: 0.5845 - 116ms/epoch - 23ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.3819 - accuracy: 0.6338 - 109ms/epoch - 22ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.2419 - accuracy: 0.6972 - 106ms/epoch - 21ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 2.1033 - accuracy: 0.6690 - 120ms/epoch - 24ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.9838 - accuracy: 0.7113 - 111ms/epoch - 22ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.8526 - accuracy: 0.7535 - 105ms/epoch - 21ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.7613 - accuracy: 0.7535 - 101ms/epoch - 20ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.6602 - accuracy: 0.7606 - 115ms/epoch - 23ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.5681 - accuracy: 0.7746 - 120ms/epoch - 24ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.4648 - accuracy: 0.8099 - 112ms/epoch - 22ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.3677 - accuracy: 0.8099 - 112ms/epoch - 22ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.2884 - accuracy: 0.8169 - 106ms/epoch - 21ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.2072 - accuracy: 0.8451 - 126ms/epoch - 25ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.1587 - accuracy: 0.8310 - 106ms/epoch - 21ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.0801 - accuracy: 0.8451 - 109ms/epoch - 22ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.0118 - accuracy: 0.8592 - 105ms/epoch - 21ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.9575 - accuracy: 0.8592 - 112ms/epoch - 22ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.9009 - accuracy: 0.8732 - 102ms/epoch - 20ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.8500 - accuracy: 0.8662 - 113ms/epoch - 23ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.7948 - accuracy: 0.8873 - 100ms/epoch - 20ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.7529 - accuracy: 0.8944 - 98ms/epoch - 20ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.7084 - accuracy: 0.8873 - 123ms/epoch - 25ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.6639 - accuracy: 0.8944 - 122ms/epoch - 24ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.6286 - accuracy: 0.9014 - 200ms/epoch - 40ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.5956 - accuracy: 0.8944 - 188ms/epoch - 38ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.5757 - accuracy: 0.9155 - 194ms/epoch - 39ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.5387 - accuracy: 0.9085 - 176ms/epoch - 35ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.5268 - accuracy: 0.9014 - 171ms/epoch - 34ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.5082 - accuracy: 0.9437 - 175ms/epoch - 35ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.4783 - accuracy: 0.9437 - 170ms/epoch - 34ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.4417 - accuracy: 0.9296 - 182ms/epoch - 36ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.4341 - accuracy: 0.9437 - 187ms/epoch - 37ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.4062 - accuracy: 0.9296 - 194ms/epoch - 39ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.3812 - accuracy: 0.9366 - 211ms/epoch - 42ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.3583 - accuracy: 0.9437 - 195ms/epoch - 39ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.3462 - accuracy: 0.9577 - 200ms/epoch - 40ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.3305 - accuracy: 0.9648 - 181ms/epoch - 36ms/step

# %%
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: earth
# Enter how many words to predict: 34
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# earth is the third planet from the sun and the only astronomical object known to harbor life and winds water to earth's one hemisphere the more hemisphere earth's liquid cosmic radiation the rivers and atmospheric water
