# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
import requests

url = "https://love-calculator.p.rapidapi.com/getPercentage"
dic={}
fname=input("Enter your name: ")
dic['first_person']=fname
sname=input("Enter your partner name: ")
dic['second_person']=sname
headers = {"X-RapidAPI-Key": "bc6ed2139cmsh22151047bb27fd7p154983jsn946c8891df23",	"X-RapidAPI-Host": "love-calculator.p.rapidapi.com"}
response = requests.get(url, headers=headers, params=dic)
print(response.json())
print("First person name: ",)

# %%
import requests
url = "https://love-calculator.p.rapidapi.com/getPercentage"
querystring={}
fname=input("enter first person name: ")
sname=input("enter second person name: ")
querystring["fname"]=fname
querystring["sname"]=sname
headers = {"X-RapidAPI-Key": "bc6ed2139cmsh22151047bb27fd7p154983jsn946c8891df23","X-RapidAPI-Host": "love-calculator.p.rapidapi.com"}
response = requests.get(url, headers=headers, params=querystring)
data=response.json()
print("****YOUR LOVE CALCULATION****")
print("First person name: ",data["fname"])
print("Second person name: ",data["sname"])
print("Percentage of love: ",data["percentage"])
print("Suggession to you: ",data["result"])

# %%
import requests

url = "https://mashape-community-urban-dictionary.p.rapidapi.com/define"

querystring = {}
term=input("Enter any word: ")
querystring["term"]=term
headers = {
	"X-RapidAPI-Key": "bc6ed2139cmsh22151047bb27fd7p154983jsn946c8891df23",
	"X-RapidAPI-Host": "mashape-community-urban-dictionary.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data=response.json()
print("Word: ",data['list'][0]['word'])
print("Definition is: ",data['list'][0]['definition'])
print("thumbs_up: ",data['list'][0]['thumbs_up'])
print("Author is: ",data['list'][0]['author'])
print("defid: ",data['list'][0]['defid'])
print("Written on: ",data['list'][0]['written_on'])
print("Example: ",data['list'][0]['example'])
